# %%
import numpy as np
import matplotlib.pyplot as plt
from cellpose import plot, utils, io
# Out:
# Welcome to CellposeSAM, cellpose v
# cellpose version: 	4.0.6
# platform:       	darwin
# python version: 	3.9.23
# torch version:  	2.7.1! The neural network component of
# CPSAM is much larger than in previous versions and CPU excution is slow.
# We encourage users to use GPU/MPS if available.

# %%
path = "/Users/mayongzhi/Desktop/FS_lab/spatial_pipeline/work/47/fa5dacfcfe4c7c1654eb24117160f3/cellpose/DAPI_E14.5_2_seg.npy"
dat = np.load(path, allow_pickle=True).item()
img = io.imread("/Users/mayongzhi/Desktop/FS_lab/dashboard/test_data/DAPI_E14.5_2_ISAP02045520_20220407.tif")

# %%
# plot image with masks overlaid
mask_RGB = plot.mask_overlay(img, dat['masks'],
                        colors=np.array(dat['colors']))

# plot image with outlines overlaid in red
outlines = utils.outlines_list(dat['masks'])
plt.imshow(img)
for o in outlines:
    plt.plot(o[:,0], o[:,1], color='r')
# Out:
# Welcome to CellposeSAM, cellpose v
# cellpose version: 	4.0.6
# platform:       	darwin
# python version: 	3.9.23
# torch version:  	2.7.1! The neural network component of
# CPSAM is much larger than in previous versions and CPU excution is slow.
# We encourage users to use GPU/MPS if available.
#
#
#
#
# Welcome to CellposeSAM, cellpose v
# cellpose version: 	4.0.6
# platform:       	darwin
# python version: 	3.9.23
# torch version:  	2.7.1! The neural network component of
# CPSAM is much larger than in previous versions and CPU excution is slow.
# We encourage users to use GPU/MPS if available.
#
#
#
#
# Welcome to CellposeSAM, cellpose v
# cellpose version: 	4.0.6
# platform:       	darwin
# python version: 	3.9.23
# torch version:  	2.7.1! The neural network component of
# CPSAM is much larger than in previous versions and CPU excution is slow.
# We encourage users to use GPU/MPS if available.
#
#
#
#
# Welcome to CellposeSAM, cellpose v
# cellpose version: 	4.0.6
# ...

# %%
label_image=dat['masks']
mask_path = "/Users/mayongzhi/Desktop/FS_lab/dashboard/test_data/DAPI_E14.5_2_ISAP02045520_20220407 (1).tif"
mask=Image.open(mask_path)
maskarray = np.array(mask)

from skimage.measure import regionprops
props = regionprops(label_image)


for z in props:
    x_pos=int(z['centroid'][0])
    y_pos=int(z['centroid'][1])
    coords=z["coords"]
    if maskarray[x_pos, y_pos]==0:
        for n in coords:
            label_image[n[0]][n[1]]=0
        

label_image1=coo_matrix(label_image)


rgb_label_image = skimage.color.label2rgb(label_image1.toarray(), bg_label=0)
_dpi = 72
plt.figure(figsize=(1500/_dpi, 1500/_dpi), dpi=_dpi)
imgplot = plt.imshow(rgb_label_image)
plt.grid(False)
#plt.savefig('{}/Cellpose_Masks/{}.tif'.format(path_Outputs, Sample))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 3
#       1 label_image=dat['masks']
#       2 mask_path = "/Users/mayongzhi/Desktop/FS_lab/dashboard/test_data/DAPI_E14.5_2_ISAP02045520_20220407 (1).tif"
# ----> 3 mask=Image.open(mask_path)
#       4 maskarray = np.array(mask)
#       6 from skimage.measure import regionprops
#
# NameError: name 'Image' is not defined

# %%
img = seg['img']
plt.imshow(img, cmap="gray")
plt.imshow(np.ma.masked_where(mask==0, mask),cmap='gray', alpha=0.4)
plt.axis('off')
# Out:
# (-0.5, 3287.5, 3503.5, -0.5)

# %%
for pts in seg['outlines']:
    plt.plot(pts[:,1], pts[:,0], 'r-', linewidth = 0.5)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 for pts in seg['outlines']:
# ----> 2     plt.plot(pts[:,1], pts[:,0], 'r-', linewidth = 0.5)
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
